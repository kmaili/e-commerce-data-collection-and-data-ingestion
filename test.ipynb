# %%
! pip install e-commerce-scraper

# %%
from e_commerce_scraper.scraper import EcommerceScraper
from kafka_producer import KafkaProducer

# %%
producer = KafkaProducer(bootstrap_servers="localhost:8097")

# %%
scraper = EcommerceScraper(

)
# Out:
# 2024-11-18 14:08:15,314:[INFO]: [19]: Using Windows local Selenium

# %%
for idx, prod in enumerate(scraper.getProductsFromMytek([1, 2], 10)):
        producer.produce(topic="mytek", key=str(idx), value=prod)
# Out:
# Element not clickable with JS after 3 seconds.
# ...
